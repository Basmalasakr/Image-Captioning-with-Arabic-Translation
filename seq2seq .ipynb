# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Attention
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 1- اقرأ الداتا من الملف
english_sentences = []
arabic_sentences = []

with open('/content/drive/MyDrive/translated_captions_cleaned .csv', 'r', encoding='utf-8') as f:
    for line in f:
        parts = line.strip().split(',')
        if len(parts) >= 2:
            english_sentences.append(parts[0])
            arabic_sentences.append(parts[1])

# %%
import re
import unicodedata

# دالة لحذف التشكيل من النصوص العربية
def remove_tashkeel(text):
    return re.sub(r'[\u0617-\u061A\u064B-\u0652]', '', text)

# دالة لتنظيف النصوص الإنجليزية والعربية
def clean_text(text):
    # إزالة التشكيل في النصوص العربية
    text = remove_tashkeel(text)

    # تحويل النصوص الإنجليزية إلى lowercase
    text = text.lower()

    # إزالة الرموز غير المطلوبة (مثل علامات الترقيم غير المفيدة)
    text = re.sub(r'[^\w\s.,?!ء-ي]', '', text)

    # إزالة المسافات الزائدة بين الكلمات
    text = re.sub(r'\s+', ' ', text)

    # إزالة المسافات الزائدة في بداية ونهاية النص
    text = text.strip()

    return text

# تنظيف الجمل الإنجليزية والعربية
english_sentences = [clean_text(sentence) for sentence in english_sentences]
arabic_sentences = [clean_text(sentence) for sentence in arabic_sentences]

# %%
# ⚡ أول حاجة: ضيفي <start> و <end> لكل جملة عربية
arabic_sentences = [f"<start> {sentence.strip()} <end>" for sentence in arabic_sentences]

# معلمات
num_samples = 24000
max_vocab_size = 10000
max_encoder_seq_length = 30
max_decoder_seq_length = 30

# تجهيز التوكنز
eng_tokenizer = Tokenizer(num_words=max_vocab_size, filters='', lower=True)
eng_tokenizer.fit_on_texts(english_sentences)
input_sequences = eng_tokenizer.texts_to_sequences(english_sentences)
input_sequences = pad_sequences(input_sequences, maxlen=max_encoder_seq_length, padding='post')

ar_tokenizer = Tokenizer(num_words=max_vocab_size, filters='', lower=False)
ar_tokenizer.fit_on_texts(arabic_sentences)
target_sequences = ar_tokenizer.texts_to_sequences(arabic_sentences)
target_sequences = pad_sequences(target_sequences, maxlen=max_decoder_seq_length, padding='post')

input_vocab_size = len(eng_tokenizer.word_index) + 1
target_vocab_size = len(ar_tokenizer.word_index) + 1

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense
from tensorflow.keras.callbacks import ModelCheckpoint

# بناء موديل Seq2Seq
encoder_inputs = Input(shape=(None,), name='encoder_inputs')
encoder_embedding = Embedding(input_vocab_size, 256, name='encoder_embedding')(encoder_inputs)
encoder_lstm = LSTM(256, return_state=True, name='encoder_lstm')
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(None,), name='decoder_inputs')
decoder_embedding = Embedding(target_vocab_size, 256, name='decoder_embedding')(decoder_inputs)
decoder_lstm = LSTM(256, return_sequences=True, return_state=True, name='decoder_lstm')
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(target_vocab_size, activation='softmax', name='decoder_dense')
decoder_outputs = decoder_dense(decoder_outputs)

# تجميع الموديل
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# كمبايل
model.compile(
    optimizer='rmsprop',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# تجهيز بيانات الديكودر
decoder_input_data = target_sequences[:, :-1]
decoder_target_data = target_sequences[:, 1:]
decoder_target_data = decoder_target_data[..., None]

# حفظ أفضل موديل
checkpoint = ModelCheckpoint(
    '/content/drive/MyDrive/seq2seq_translation_model.keras',
    save_best_only=True,
    monitor='val_loss',
    verbose=1
)
# تدريب
history = model.fit(
    [input_sequences, decoder_input_data],
    decoder_target_data,
    batch_size=64,
    epochs=50,
    validation_split=0.2,
    callbacks=[checkpoint]
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_inputs      │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_inputs      │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_embedding   │ (None, None, 256) │  1,773,824 │ encoder_inputs[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_embedding   │ (None, None, 256) │  4,337,408 │ decoder_inputs[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_lstm (LSTM) │ [(None, 256),     │    525,312 │ encoder_embeddin… │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_lstm (LSTM) │ [(None, None,     │    525,312 │ decoder_embeddin… │
# │                     │ 256), (None,      │            │ encoder_lstm[0][… │
# │                     │ 256), (None,      │            │ encoder_lstm[0][… │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_dense       │ (None, None,      │  4,354,351 │ decoder_lstm[0][… │
# │ (Dense)             │ 16943)            │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,516,207 (43.93 MB)
#  Trainable params: 11,516,207 (43.93 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7172 - loss: 3.0207
# Epoch 1: val_loss improved from inf to 1.68947, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 107ms/step - accuracy: 0.7174 - loss: 3.0150 - val_accuracy: 0.7705 - val_loss: 1.6895
# Epoch 2/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7577 - loss: 1.7383
# Epoch 2: val_loss improved from 1.68947 to 1.67069, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.7577 - loss: 1.7383 - val_accuracy: 0.7704 - val_loss: 1.6707
# Epoch 3/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7585 - loss: 1.7027
# Epoch 3: val_loss improved from 1.67069 to 1.61692, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.7585 - loss: 1.7026 - val_accuracy: 0.7748 - val_loss: 1.6169
# Epoch 4/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7619 - loss: 1.6523
# Epoch 4: val_loss improved from 1.61692 to 1.56995, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 86ms/step - accuracy: 0.7619 - loss: 1.6522 - val_accuracy: 0.7774 - val_loss: 1.5700
# Epoch 5/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7652 - loss: 1.5955
# Epoch 5: val_loss improved from 1.56995 to 1.53857, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.7652 - loss: 1.5954 - val_accuracy: 0.7767 - val_loss: 1.5386
# Epoch 6/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7685 - loss: 1.5495
# Epoch 6: val_loss improved from 1.53857 to 1.50596, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.7685 - loss: 1.5495 - val_accuracy: 0.7786 - val_loss: 1.5060
# Epoch 7/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7700 - loss: 1.5227
# Epoch 7: val_loss improved from 1.50596 to 1.46890, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 25s 79ms/step - accuracy: 0.7700 - loss: 1.5226 - val_accuracy: 0.7832 - val_loss: 1.4689
# Epoch 8/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7741 - loss: 1.4849
# Epoch 8: val_loss improved from 1.46890 to 1.43222, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - accuracy: 0.7742 - loss: 1.4848 - val_accuracy: 0.7888 - val_loss: 1.4322
# Epoch 9/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7806 - loss: 1.4234
# Epoch 9: val_loss improved from 1.43222 to 1.40920, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 88ms/step - accuracy: 0.7806 - loss: 1.4234 - val_accuracy: 0.7895 - val_loss: 1.4092
# Epoch 10/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7830 - loss: 1.3964
# Epoch 10: val_loss improved from 1.40920 to 1.37969, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 38s 80ms/step - accuracy: 0.7830 - loss: 1.3964 - val_accuracy: 0.7928 - val_loss: 1.3797
# Epoch 11/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7848 - loss: 1.3755
# Epoch 11: val_loss improved from 1.37969 to 1.36732, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - accuracy: 0.7849 - loss: 1.3755 - val_accuracy: 0.7929 - val_loss: 1.3673
# Epoch 12/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7870 - loss: 1.3432
# Epoch 12: val_loss improved from 1.36732 to 1.33200, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 87ms/step - accuracy: 0.7870 - loss: 1.3431 - val_accuracy: 0.7978 - val_loss: 1.3320
# Epoch 13/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7909 - loss: 1.3103
# Epoch 13: val_loss improved from 1.33200 to 1.30663, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 79ms/step - accuracy: 0.7909 - loss: 1.3102 - val_accuracy: 0.7979 - val_loss: 1.3066
# Epoch 14/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7955 - loss: 1.2745
# Epoch 14: val_loss improved from 1.30663 to 1.28168, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 87ms/step - accuracy: 0.7955 - loss: 1.2745 - val_accuracy: 0.8035 - val_loss: 1.2817
# Epoch 15/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7991 - loss: 1.2434
# Epoch 15: val_loss improved from 1.28168 to 1.26234, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 38s 79ms/step - accuracy: 0.7991 - loss: 1.2434 - val_accuracy: 0.8055 - val_loss: 1.2623
# Epoch 16/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8014 - loss: 1.2223
# Epoch 16: val_loss improved from 1.26234 to 1.24650, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 87ms/step - accuracy: 0.8014 - loss: 1.2223 - val_accuracy: 0.8072 - val_loss: 1.2465
# Epoch 17/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8058 - loss: 1.1913
# Epoch 17: val_loss improved from 1.24650 to 1.22757, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 86ms/step - accuracy: 0.8058 - loss: 1.1913 - val_accuracy: 0.8103 - val_loss: 1.2276
# Epoch 18/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8073 - loss: 1.1776
# Epoch 18: val_loss improved from 1.22757 to 1.20557, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 80ms/step - accuracy: 0.8073 - loss: 1.1776 - val_accuracy: 0.8135 - val_loss: 1.2056
# Epoch 19/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8118 - loss: 1.1458
# Epoch 19: val_loss improved from 1.20557 to 1.19270, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - accuracy: 0.8118 - loss: 1.1459 - val_accuracy: 0.8152 - val_loss: 1.1927
# Epoch 20/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8144 - loss: 1.1235
# Epoch 20: val_loss improved from 1.19270 to 1.17443, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - accuracy: 0.8144 - loss: 1.1235 - val_accuracy: 0.8175 - val_loss: 1.1744
# Epoch 21/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8173 - loss: 1.1010
# Epoch 21: val_loss improved from 1.17443 to 1.16301, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - accuracy: 0.8173 - loss: 1.1010 - val_accuracy: 0.8188 - val_loss: 1.1630
# Epoch 22/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8199 - loss: 1.0812
# Epoch 22: val_loss improved from 1.16301 to 1.15247, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 80ms/step - accuracy: 0.8199 - loss: 1.0812 - val_accuracy: 0.8211 - val_loss: 1.1525
# Epoch 23/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8215 - loss: 1.0637
# Epoch 23: val_loss improved from 1.15247 to 1.13866, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 87ms/step - accuracy: 0.8215 - loss: 1.0637 - val_accuracy: 0.8218 - val_loss: 1.1387
# Epoch 24/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8237 - loss: 1.0473
# Epoch 24: val_loss improved from 1.13866 to 1.12386, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 38s 79ms/step - accuracy: 0.8237 - loss: 1.0473 - val_accuracy: 0.8240 - val_loss: 1.1239
# Epoch 25/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8250 - loss: 1.0311
# Epoch 25: val_loss improved from 1.12386 to 1.11243, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - accuracy: 0.8250 - loss: 1.0310 - val_accuracy: 0.8257 - val_loss: 1.1124
# Epoch 26/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8277 - loss: 1.0100
# Epoch 26: val_loss improved from 1.11243 to 1.10631, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 87ms/step - accuracy: 0.8277 - loss: 1.0100 - val_accuracy: 0.8264 - val_loss: 1.1063
# Epoch 27/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8295 - loss: 0.9963
# Epoch 27: val_loss did not improve from 1.10631
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 86ms/step - accuracy: 0.8295 - loss: 0.9962 - val_accuracy: 0.8254 - val_loss: 1.1095
# Epoch 28/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8333 - loss: 0.9698
# Epoch 28: val_loss improved from 1.10631 to 1.08689, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.8333 - loss: 0.9698 - val_accuracy: 0.8292 - val_loss: 1.0869
# Epoch 29/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8352 - loss: 0.9510
# Epoch 29: val_loss improved from 1.08689 to 1.07932, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.8352 - loss: 0.9511 - val_accuracy: 0.8304 - val_loss: 1.0793
# Epoch 30/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8371 - loss: 0.9377
# Epoch 30: val_loss improved from 1.07932 to 1.07697, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.8371 - loss: 0.9377 - val_accuracy: 0.8304 - val_loss: 1.0770
# Epoch 31/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8384 - loss: 0.9207
# Epoch 31: val_loss improved from 1.07697 to 1.05944, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.8384 - loss: 0.9207 - val_accuracy: 0.8335 - val_loss: 1.0594
# Epoch 32/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8401 - loss: 0.9103
# Epoch 32: val_loss improved from 1.05944 to 1.05212, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.8401 - loss: 0.9103 - val_accuracy: 0.8348 - val_loss: 1.0521
# Epoch 33/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8433 - loss: 0.8866
# Epoch 33: val_loss did not improve from 1.05212
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 86ms/step - accuracy: 0.8433 - loss: 0.8866 - val_accuracy: 0.8339 - val_loss: 1.0524
# Epoch 34/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8453 - loss: 0.8695
# Epoch 34: val_loss improved from 1.05212 to 1.03714, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 80ms/step - accuracy: 0.8453 - loss: 0.8695 - val_accuracy: 0.8369 - val_loss: 1.0371
# Epoch 35/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8474 - loss: 0.8538
# Epoch 35: val_loss improved from 1.03714 to 1.03223, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 88ms/step - accuracy: 0.8474 - loss: 0.8538 - val_accuracy: 0.8375 - val_loss: 1.0322
# Epoch 36/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8485 - loss: 0.8405
# Epoch 36: val_loss improved from 1.03223 to 1.02320, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 38s 79ms/step - accuracy: 0.8485 - loss: 0.8405 - val_accuracy: 0.8388 - val_loss: 1.0232
# Epoch 37/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8509 - loss: 0.8209
# Epoch 37: val_loss improved from 1.02320 to 1.02203, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 88ms/step - accuracy: 0.8509 - loss: 0.8209 - val_accuracy: 0.8384 - val_loss: 1.0220
# Epoch 38/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8529 - loss: 0.8068
# Epoch 38: val_loss improved from 1.02203 to 1.01413, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 88ms/step - accuracy: 0.8529 - loss: 0.8068 - val_accuracy: 0.8396 - val_loss: 1.0141
# Epoch 39/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8545 - loss: 0.7939
# Epoch 39: val_loss improved from 1.01413 to 1.00725, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 38s 79ms/step - accuracy: 0.8545 - loss: 0.7939 - val_accuracy: 0.8409 - val_loss: 1.0072
# Epoch 40/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8561 - loss: 0.7806
# Epoch 40: val_loss improved from 1.00725 to 1.00252, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 87ms/step - accuracy: 0.8561 - loss: 0.7806 - val_accuracy: 0.8416 - val_loss: 1.0025
# Epoch 41/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8591 - loss: 0.7610
# Epoch 41: val_loss improved from 1.00252 to 0.99569, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 80ms/step - accuracy: 0.8591 - loss: 0.7610 - val_accuracy: 0.8431 - val_loss: 0.9957
# Epoch 42/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8601 - loss: 0.7511
# Epoch 42: val_loss improved from 0.99569 to 0.99041, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 87ms/step - accuracy: 0.8601 - loss: 0.7511 - val_accuracy: 0.8430 - val_loss: 0.9904
# Epoch 43/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8621 - loss: 0.7341
# Epoch 43: val_loss did not improve from 0.99041
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - accuracy: 0.8621 - loss: 0.7341 - val_accuracy: 0.8436 - val_loss: 0.9907
# Epoch 44/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8636 - loss: 0.7210
# Epoch 44: val_loss improved from 0.99041 to 0.98486, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 87ms/step - accuracy: 0.8636 - loss: 0.7210 - val_accuracy: 0.8437 - val_loss: 0.9849
# Epoch 45/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8653 - loss: 0.7071
# Epoch 45: val_loss improved from 0.98486 to 0.98088, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.8653 - loss: 0.7072 - val_accuracy: 0.8446 - val_loss: 0.9809
# Epoch 46/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8677 - loss: 0.6946
# Epoch 46: val_loss improved from 0.98088 to 0.97508, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - accuracy: 0.8677 - loss: 0.6946 - val_accuracy: 0.8453 - val_loss: 0.9751
# Epoch 47/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8690 - loss: 0.6797
# Epoch 47: val_loss did not improve from 0.97508
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.8690 - loss: 0.6798 - val_accuracy: 0.8456 - val_loss: 0.9788
# Epoch 48/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8710 - loss: 0.6680
# Epoch 48: val_loss improved from 0.97508 to 0.97212, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - accuracy: 0.8710 - loss: 0.6681 - val_accuracy: 0.8463 - val_loss: 0.9721
# Epoch 49/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8724 - loss: 0.6583
# Epoch 49: val_loss improved from 0.97212 to 0.96673, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - accuracy: 0.8724 - loss: 0.6583 - val_accuracy: 0.8465 - val_loss: 0.9667
# Epoch 50/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8735 - loss: 0.6465
# Epoch 50: val_loss improved from 0.96673 to 0.96336, saving model to /content/drive/MyDrive/seq2seq_translation_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - accuracy: 0.8735 - loss: 0.6465 - val_accuracy: 0.8479 - val_loss: 0.9634

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/seq2seq_translation_model.keras')

# %%
import pickle

# حفظ التوكنيزر الإنجليزي بعد التدريب
with open('/content/drive/MyDrive/eng_tokenizer.pkl', 'wb') as f:
    pickle.dump(eng_tokenizer, f)

# حفظ التوكنيزر العربي بعد التدريب
with open('/content/drive/MyDrive/ar_tokenizer.pkl', 'wb') as f:
    pickle.dump(ar_tokenizer, f)

# %%
encoder_model = Model(encoder_inputs, encoder_states)

# %%
# مكان جديد لمدخل الحالات الخفية
decoder_state_input_h = Input(shape=(256,), name='input_h')
decoder_state_input_c = Input(shape=(256,), name='input_c')
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

# نعيد استخدام الـ embedding والـ LSTM من نفس الموديل
decoder_embedding2 = decoder_embedding
decoder_outputs2, state_h2, state_c2 = decoder_lstm(
    decoder_embedding2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]
decoder_outputs2 = decoder_dense(decoder_outputs2)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs2] + decoder_states2
)

# %%
def decode_sequence(input_seq):
    # استخراج الحالات الخفية من الانكودر
    states_value = encoder_model.predict(input_seq)

    # تحضير البداية
    target_seq = np.zeros((1, 1))
    # Changed target_tokenizer to ar_tokenizer
    target_seq[0, 0] = ar_tokenizer.word_index['<start>']

    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        # Changed target_tokenizer to ar_tokenizer
        sampled_word = ar_tokenizer.index_word.get(sampled_token_index, '')

        if sampled_word == '<end>' or len(decoded_sentence.split()) > max_decoder_seq_length:
            stop_condition = True
        else:
            decoded_sentence += ' ' + sampled_word

        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        states_value = [h, c]

    return decoded_sentence.strip()

# %%
# مثال على جملة
test_sentence = "A dog is running in the snow"
seq = eng_tokenizer.texts_to_sequences([test_sentence]) # Changed input_tokenizer to eng_tokenizer
seq = tf.keras.preprocessing.sequence.pad_sequences(seq, maxlen=max_encoder_seq_length, padding='post')

translated = decode_sequence(seq)
print("الترجمة:", translated)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# الترجمة: الكلب يركض في الثلج.

# %%
# مثال على جملة
test_sentence = "Three people hang out on top of a big hill"
seq = eng_tokenizer.texts_to_sequences([test_sentence]) # Changed input_tokenizer to eng_tokenizer
seq = tf.keras.preprocessing.sequence.pad_sequences(seq, maxlen=max_encoder_seq_length, padding='post')

translated = decode_sequence(seq)
print("الترجمة:", translated)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# الترجمة: ثلاثة أشخاص على قمة تلة كبيرة.

# %%
# مثال على جملة
test_sentence = "A girls plays in the surf"
seq = eng_tokenizer.texts_to_sequences([test_sentence]) # Changed input_tokenizer to eng_tokenizer
seq = tf.keras.preprocessing.sequence.pad_sequences(seq, maxlen=max_encoder_seq_length, padding='post')

translated = decode_sequence(seq)
print("الترجمة:", translated)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# الترجمة: الفتيات يلعبن في الملعب.

# %%
# مثال على جملة
test_sentence = "A group of people gathered around in the dark"
seq = eng_tokenizer.texts_to_sequences([test_sentence]) # Changed input_tokenizer to eng_tokenizer
seq = tf.keras.preprocessing.sequence.pad_sequences(seq, maxlen=max_encoder_seq_length, padding='post')

translated = decode_sequence(seq)
print("الترجمة:", translated)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# الترجمة: مجموعة من الناس ينتظرون في الليل.

# %%
# مثال على جملة
test_sentence = "A man drives a jeep over rough rocks"
seq = eng_tokenizer.texts_to_sequences([test_sentence]) # Changed input_tokenizer to eng_tokenizer
seq = tf.keras.preprocessing.sequence.pad_sequences(seq, maxlen=max_encoder_seq_length, padding='post')

translated = decode_sequence(seq)
print("الترجمة:", translated)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# الترجمة: رجل يقود دراجة فوق منحدر صخري.

# %%
# مثال على جملة
test_sentence = "A fat dog sitting in a boat"
seq = eng_tokenizer.texts_to_sequences([test_sentence]) # Changed input_tokenizer to eng_tokenizer
seq = tf.keras.preprocessing.sequence.pad_sequences(seq, maxlen=max_encoder_seq_length, padding='post')

translated = decode_sequence(seq)
print("الترجمة:", translated)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# الترجمة: كلب يجلس في الخارج في الثلج.

# %%
# مثال على جملة
test_sentence = "Three boys diving into a lake"
seq = eng_tokenizer.texts_to_sequences([test_sentence]) # Changed input_tokenizer to eng_tokenizer
seq = tf.keras.preprocessing.sequence.pad_sequences(seq, maxlen=max_encoder_seq_length, padding='post')

translated = decode_sequence(seq)
print("الترجمة:", translated)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# الترجمة: ثلاثة أولاد يغوصون في بحيرة.
